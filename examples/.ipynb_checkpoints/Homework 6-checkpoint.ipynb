# %% [markdown]
# # Homework 6
#
# Camille Girard
#
# MIT License: https://opensource.org/licenses/MIT

# %%
# Configure Jupyter so figures appear in the notebook
# %matplotlib inline

# Configure Jupyter to display the assigned value after an assignment
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'

import numpy as np
import pandas as pd

from scipy.stats import norm, poisson

# import classes from thinkbayes2
from thinkbayes2 import Pmf, Cdf, Suite, Joint
import scipy as sp

import thinkbayes2
import thinkplot

import pymc3 as pm
import theano.tensor as T


from matplotlib import pyplot as plt
# Out:
# ERROR:root:The 'ast_node_interactivity' trait of a ZMQInteractiveShell instance must be any of ['all', 'last', 'last_expr', 'none'], but a value of 'last_expr_or_assign' <class 'str'> was specified.
# /home/cgirard/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## The Nile Problem

# %% [markdown]
# The nile rivers trends seem to have quickly changed at some point - this is an analysis of where and how much that change was.
#
# First use a changepoint algorithim in pymc in order to identify when the mean changed and to have the normal distributions for the means in each half.

# %%
import statsmodels.api as sm

data = sm.datasets.nile.load()

# %%
nile = sm.datasets.get_rdataset("Nile")
nile.data.head()
# Out:
#    time  value
# 0  1871   1120
# 1  1872   1160
# 2  1873    963
# 3  1874   1210
# 4  1875   1160

# %%
data = nile.data['value']
print(data.head())
# Out:
# 0    1120
# 1    1160
# 2     963
# 3    1210
# 4    1160
# Name: value, dtype: int64

# %%
nile.data['value'].plot()

# %% [markdown]
# ### Mean Based Changepoint

# %%
niter = 100000
t = range(len(data))
with pm.Model() as change_point:
    cp = pm.DiscreteUniform('change_point', lower=0, upper=len(data))
    mu0 = pm.Uniform('mu0', 500,1200)
    mu1 = pm.Uniform('mu1', 500,1200)
    mu = T.switch(t < cp, mu0, mu1)
    Y_obs = pm.Normal('Y_obs', mu=mu, sd = data.mean(), observed=data)
    trace = pm.sample(niter)
# Out:
# Sampling 4 chains: 100%|██████████| 402000/402000 [01:36<00:00, 4159.19draws/s]

# %%
pm.traceplot(trace, varnames=['change_point', 'mu0', 'mu1'])
pass

# %% [markdown]
# With all the noise the model (caused by the fluctuation of the tide) is not very convinced that the changepoint is at 30, however there is a  small spike. The means are also relatively different, with the earlier mean being higher, fitting with the plot given by the data.

# %% [markdown]
# ### Change in the Regression
#
# It also seems that there is a change in the regression before and after the changepoint. For this I will calculate a regression before at after 30, which is around where the change happens, and will see what this shows.

# %%
first = nile.data['value'][0:30]
t1 = nile.data['time'][0:30]
second = nile.data['value'][30:]
t2 = nile.data['time'][30:]

# %%
with pm.Model() as model:
    slope = pm.Uniform('slope', -10, 10)
    inter = pm.Uniform('inter', 100, 10000)
    sigma = pm.Uniform('sigma', 0, 1000)

    y_est = slope* (t1-1870) + inter
    y = pm.Normal('y', mu=y_est, sd=sigma, observed= first)
    trace = pm.sample(4000, tune=20000)
# Out:
# Sampling 4 chains: 100%|██████████| 96000/96000 [00:32<00:00, 2993.81draws/s]
# WARNING:pymc3:The acceptance probability does not match the target. It is 0.4774617955077266, but should be close to 0.8. Try to increase the number of tuning steps.

# %%
pm.traceplot(trace, varnames=['slope', 'inter', 'sigma'])
pass

# %%
with pm.Model() as model:
    slope = pm.Uniform('slope', -10, 10)
    inter = pm.Uniform('inter', 100, 10000)
    sigma = pm.Uniform('sigma', 0, 1000)

    y_est = slope* (t2 - nile.data['time'][30]) + inter
    y = pm.Normal('y', mu=y_est, sd=sigma, observed=second)
    trace = pm.sample(4000, tune=25000)
# Out:
# Sampling 4 chains: 100%|██████████| 116000/116000 [00:35<00:00, 3305.06draws/s]
# WARNING:pymc3:The acceptance probability does not match the target. It is 0.6304996133227596, but should be close to 0.8. Try to increase the number of tuning steps.

# %%
pm.traceplot(trace, varnames=['slope', 'inter', 'sigma'])
pass

# %% [markdown]
# With a dividing time of 30, which is somewhere in the range of the bump of the changepoint there is an observed difference in the slope, intercept and the sigma. Before the changepoint there is a negative slope of about -2.5 and a higher intercept of about 1100 and a higher sigma. Afterwards the slope is positive but about 0.5 and the intercept is lower as well as the sigma.
#
# This fits with the plot of the data, as the beginning the level is dropping starting at a higher point and having a bigger fluctuation. After the point the level has less fluctuation and is more constant.

# %% [markdown]
# ### Combining the Regression and Change Point

# %% [markdown]
# Instead of doing changepoint with the mean, use two regression parameters to find the changepoint and the components of each side of the changepoint.

# %%
t = range(len(data))
with pm.Model() as model:
    cp = pm.DiscreteUniform('change_point', lower=0, upper=len(data))
    
    s1 = pm.Uniform('slope1', -15, 10)
    i1 = pm.Uniform('inter1', 850, 1400)
    si1 = pm.Uniform('sigma1', 100, 250)
    s2= pm.Uniform('slope2', -4, 4)
    i2=pm.Uniform('inter2', 400, 1200)
    si2 = pm.Uniform('sigma2', 80, 200)
    
    slope = T.switch(t < cp, s1, s2)
    inter = T.switch(t < cp, i1, i2)
    sigma = T.switch(t < cp, si1, si2)
    
    y_est = slope* (nile.data['time']-1870) + inter
    y = pm.Normal('y', mu=y_est, sd=sigma, observed=nile.data['value'])
    trace = pm.sample(100000, tune=100000)
# Out:
# Sampling 4 chains: 100%|██████████| 800000/800000 [09:09<00:00, 1457.13draws/s]
# ERROR:pymc3:There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# ERROR:pymc3:There were 12 divergences after tuning. Increase `target_accept` or reparameterize.
# ERROR:pymc3:There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# ERROR:pymc3:There were 6 divergences after tuning. Increase `target_accept` or reparameterize.
# ERROR:pymc3:The estimated number of effective samples is smaller than 200 for some parameters.

# %%
pm.traceplot(trace, varnames=['change_point', 'slope1', 'inter1', 'sigma1', 'slope2', 'inter2', 'sigma2'])
pass

# %% [markdown]
# By combining the changepoint and the regression model there is a clearer changepoint location at 28 than the previous model, due to the reduction of the effect of the fluctuation which is now put into the sigma. The slopes, intercepts and sigmas are very similar to those collected by running the regression on each side of the changepoint of the mu which shows consistancy between the two methods. One larger difference is that the slope 1 has some more fluctuation, it is less sure than when the data is divided, but still has a slope that is leaning into the slightly negative side.

# %% [markdown]
# ### We Have 2 Possible Changepoints...

# %% [markdown]
# The slope at the beginning of the changepoint being bimodal means that there are two potential changepoints. This is also shown in the changepoint data, where there is a small bump up later in the data for another possible changepoint. In order to observe how these two sides of either changepoint behave we will run the model with both halves.
#
# Lets split the data at 40 for the beginning and start at 35 for the end and run the model

# %%
first_half = nile.data['value'][0:41]
time1 = nile.data['time'][0:41]
second_half = nile.data['value'][35:]
time2 = nile.data['time'][35:]

# %%
t = range(len(first_half))
with pm.Model() as model:
    cp = pm.DiscreteUniform('change_point', lower=0, upper=len(first_half))
    
    s1 = pm.Uniform('slope1', -15, 10)
    i1 = pm.Uniform('inter1', 850, 1400)
    si1 = pm.Uniform('sigma1', 100, 250)
    s2= pm.Uniform('slope2', -10, 25)
    i2=pm.Uniform('inter2', -100, 1200)
    si2 = pm.Uniform('sigma2', 30, 200)
    
    slope = T.switch(t < cp, s1, s2)
    inter = T.switch(t < cp, i1, i2)
    sigma = T.switch(t < cp, si1, si2)
    
    y_est = slope * (time1 - 1870) + inter
    y = pm.Normal('y', mu=y_est, sd=sigma, observed=first_half)
    trace = pm.sample(10000, tune=10000)
# Out:
# Sampling 4 chains: 100%|██████████| 80000/80000 [01:58<00:00, 676.98draws/s]
# ERROR:pymc3:There were 9 divergences after tuning. Increase `target_accept` or reparameterize.
# ERROR:pymc3:There were 12 divergences after tuning. Increase `target_accept` or reparameterize.
# ERROR:pymc3:There were 55 divergences after tuning. Increase `target_accept` or reparameterize.
# ERROR:pymc3:There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# ERROR:pymc3:The estimated number of effective samples is smaller than 200 for some parameters.

# %%
pm.traceplot(trace, varnames=['change_point', 'slope1', 'inter1', 'sigma1', 'slope2', 'inter2', 'sigma2'])
pass

# %% [markdown]
# With the changepoint analysis on the first points of the data until 40 the changepoint occurs at 28, where it was said to in the whole analysis. The slope for the beginning of the data is positive, which is not what was expected to happen here, it was expected to be negative. The slope afterwards becomes very positive which is also a little shocking, as it is at about 12.
#
# The reason these slopes are positive in part is because of the intercept for both. The intercept is lower than before, which will explain why the slope is increasing, meaning the model will still fit the data fairly well.
#
# Not having a lot of data on either side can contribute to these suprising findings, the changepoint seems accurate with the data, however the regressions do not seems to fit as expected with the previous alogrithims.

# %%
t = range(len(second_half))
with pm.Model() as model:
    cp = pm.DiscreteUniform('change_point', lower=0, upper=len(second_half))
    
    s1 = pm.Uniform('slope1', -50, 50)
    i1 = pm.Uniform('inter1', 500, 1400)
    si1 = pm.Uniform('sigma1', 100, 400)
    s2= pm.Uniform('slope2', -4, 4)
    i2=pm.Uniform('inter2', 400, 1200)
    si2 = pm.Uniform('sigma2', 80, 200)
    
    slope = T.switch(t < cp, s1, s2)
    inter = T.switch(t < cp, i1, i2)
    sigma = T.switch(t < cp, si1, si2)
    
    y_est = slope * (time2 - 1906) + inter
    y = pm.Normal('y', mu=y_est, sd=sigma, observed=second_half)
    trace = pm.sample(20000, tune=20000)
# Out:
# Sampling 4 chains: 100%|██████████| 160000/160000 [02:28<00:00, 1077.11draws/s]
# ERROR:pymc3:There were 64 divergences after tuning. Increase `target_accept` or reparameterize.
# ERROR:pymc3:There were 287 divergences after tuning. Increase `target_accept` or reparameterize.
# ERROR:pymc3:There were 73 divergences after tuning. Increase `target_accept` or reparameterize.
# ERROR:pymc3:There were 99 divergences after tuning. Increase `target_accept` or reparameterize.
# WARNING:pymc3:The number of effective samples is smaller than 10% for some parameters.

# %%
pm.traceplot(trace, varnames=['change_point', 'slope1', 'inter1', 'sigma1', 'slope2', 'inter2', 'sigma2'])
pass

# %% [markdown]
# When we do a changepoint anaylsis with the regression on the data after 35 points of the data the results are slightly different than with the entire data. There is a changepoint found at about 13 points in, meaning at about 48 in the entire data. Between 35 and 48 there seems to be a flat zone, where the slope is about 0. Afterwards the slope goes up to about 1 which is slightly higher than the second half slope with the whole data. This shows there is likely a flat period and then the tide begins to increase.
#
# It is likely that this data has two changepoints, and that one is a much greater change in trend than the other. It is difficult to make models that fit the data very well with the limited data that is given, and this makes the models that split the data even harder to understand. The noise also will confuse the model in some situations which can cause some outliers.

# %% [markdown]
# ## Crime Data Changepoint Problem

# %% [markdown]
# This is from the notes on change-point in class. Observing if and when a change happened in the time between homocides and shootings with a firearm.

# %%
# !wget https://raw.githubusercontent.com/baltimore-sun-data/2018-shootings-analysis/master/BPD_Part_1_Victim_Based_Crime_Data.csv;
# Out:
# --2018-12-04 14:07:36--  https://raw.githubusercontent.com/baltimore-sun-data/2018-shootings-analysis/master/BPD_Part_1_Victim_Based_Crime_Data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45658084 (44M) [text/plain]
# Saving to: ‘BPD_Part_1_Victim_Based_Crime_Data.csv.5’
#
# BPD_Part_1_Victim_B 100%[===================>]  43.54M  13.6MB/s    in 3.4s
#
# 2018-12-04 14:07:40 (13.0 MB/s) - ‘BPD_Part_1_Victim_Based_Crime_Data.csv.5’ saved [45658084/45658084]

# %%
df = pd.read_csv('BPD_Part_1_Victim_Based_Crime_Data.csv', parse_dates=[0])
df.head()
# Out:
#    CrimeDate CrimeTime CrimeCode               Location     Description  \
# 0 2018-07-07  23:53:00        1F       1600 PENTWOOD RD        HOMICIDE
# 1 2018-07-07  23:50:00        4E       ST & DIVISION ST  COMMON ASSAULT
# 2 2018-07-07  23:18:00        4C  2500 PERRING MANOR RD    AGG. ASSAULT
# 3 2018-07-07  22:41:00        9S      3700 S HANOVER ST        SHOOTING
# 4 2018-07-07  22:55:00        4E  LOMBARD ST & LIGHT ST  COMMON ASSAULT
#
#   Inside/Outside   Weapon   Post      District               Neighborhood  \
# 0            NaN  FIREARM  413.0  NORTHEASTERN  Stonewood-Pentwood-Winsto
# 1              O      NaN  131.0       CENTRAL              Druid Heights
# 2              I    OTHER  423.0  NORTHEASTERN             Hamilton Hills
# 3            NaN  FIREARM  913.0      SOUTHERN                   Brooklyn
# 4              I      NaN  111.0       CENTRAL               Inner Harbor
#
#    Longitude  Latitude             Location 1     Premise  crimeCaseNumber  \
# ...

# %%
shootings = df[df.Description.isin(['HOMICIDE', 'SHOOTING']) & (df.Weapon == 'FIREARM')]

# %%
grouped = shootings.groupby('CrimeDate')

# %%
counts = grouped['Total Incidents'].sum()
counts.head()
# Out:
# CrimeDate
# 2012-01-01    1.0
# 2012-01-03    2.0
# 2012-01-05    1.0
# 2012-01-06    2.0
# 2012-01-07    3.0
# Name: Total Incidents, dtype: float64

# %%
index = pd.date_range(counts.index[0], counts.index[-1])
counts = counts.reindex(index, fill_value=0)
counts.head()
# Out:
# 2012-01-01    1.0
# 2012-01-02    0.0
# 2012-01-03    2.0
# 2012-01-04    0.0
# 2012-01-05    1.0
# Freq: D, Name: Total Incidents, dtype: float64

# %%
counts.plot()

# %%
niter = 60000
t = range(len(counts))
with pm.Model() as change_point:
    cp = pm.DiscreteUniform('change_point', lower=0, upper=len(counts), testval=len(counts)//2)
    mu0 = pm.Exponential('lam0', 1/counts.mean())
    mu1 = pm.Exponential('lam1', 1/counts.mean())
    mu = T.switch(t < cp, mu0, mu1)
    Y_obs = pm.Poisson('Y_obs', mu=mu, observed=counts)
    trace = pm.sample(niter)
# Out:
# Sampling 4 chains: 100%|██████████| 242000/242000 [01:12<00:00, 3337.98draws/s]
# WARNING:pymc3:The number of effective samples is smaller than 10% for some parameters.

# %%
pm.traceplot(trace, varnames=['change_point', 'lam0', 'lam1'])
pass

# %% [markdown]
# There seems to have been a change in the time between firearm homicides or shootings after the changepoint. The changpoint occurs between day 1200 and 1215, afterwards the time between firearm crimes seems to go up to about 2.7 from about 1.5. The lamdas have little difference between each sample however the change point seems to not be at a specific date but contained between a set of about 15 days.

# %% [markdown]
# ## SAT Language Scores Impact from Years Learned

# %% [markdown]
# It is easy to assume that the more years you learn a language the better you will do on the SAT, this analysis is to confirm that it indeed does, and to see how the effect differs on four of the most commmon languages, french, german, spanish and italian.

# %%
loc = "/home/cgirard/ThinkBayes2/examples/"
document = loc + "sat.csv"
dv = pd.read_csv(document)
dv.head()
# Out:
#    years  french_mean  french_sd  german_mean  german_sd  spanish_mean  \
# 0      2          539        126          506        112           581
# 1      3          558        109          551        110           571
# 2      4          594        108          592        113           595
# 3     16          739         90          709        103           715
#
#    spanish_sd  italian_mean  italian_sd
# 0         132           559         120
# 1         112           600         117
# 2         102           631         106
# 3          84           740          89

# %% [markdown]
# 16 years represents a native speaker, this is just an assumption about the amount of years that the student has been able to speak the language.

# %%
with pm.Model() as model:
    slope = pm.Uniform('slope',0,25)
    inter = pm.Uniform('inter', 400, 700)
    sigma = pm.Uniform('sigma', 0, 100)

    y_est = slope* dv['years'] + inter
    y = pm.Normal('y', mu=y_est, sd=sigma, observed=dv['french_mean'])
    trace = pm.sample(10000, tune=30000)
# Out:
# Sampling 4 chains: 100%|██████████| 160000/160000 [00:59<00:00, 2669.50draws/s]
# ERROR:pymc3:There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# ERROR:pymc3:There were 7 divergences after tuning. Increase `target_accept` or reparameterize.
# ERROR:pymc3:There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# ERROR:pymc3:There were 6 divergences after tuning. Increase `target_accept` or reparameterize.

# %%
pm.traceplot(trace, varnames=['slope', 'inter', 'sigma'])
pass

# %%
with pm.Model() as model:
    slope = pm.Uniform('slope',0,30)
    inter = pm.Uniform('inter', 400, 700)
    sigma = pm.Uniform('sigma', 0, 100)

    y_est = slope* dv['years'] + inter
    y = pm.Normal('y', mu=y_est, sd=sigma, observed=dv['german_mean'])
    trace = pm.sample(10000, tune=30000)
# Out:
# Sampling 4 chains: 100%|██████████| 160000/160000 [00:56<00:00, 2824.40draws/s]
# ERROR:pymc3:There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# ERROR:pymc3:There were 31 divergences after tuning. Increase `target_accept` or reparameterize.
# WARNING:pymc3:The acceptance probability does not match the target. It is 0.6959927139574997, but should be close to 0.8. Try to increase the number of tuning steps.
# WARNING:pymc3:The acceptance probability does not match the target. It is 0.9215369750736284, but should be close to 0.8. Try to increase the number of tuning steps.
# ERROR:pymc3:There were 8 divergences after tuning. Increase `target_accept` or reparameterize.

# %%
pm.traceplot(trace, varnames=['slope', 'inter', 'sigma'])
pass

# %%
with pm.Model() as model:
    slope = pm.Uniform('slope',0,20)
    inter = pm.Uniform('inter', 400, 700)
    sigma = pm.Uniform('sigma', 0, 40)

    y_est = slope* dv['years'] + inter
    y = pm.Normal('y', mu=y_est, sd=sigma, observed=dv['spanish_mean'])
    trace = pm.sample(10000, tune=30000)
# Out:
# Sampling 4 chains: 100%|██████████| 160000/160000 [00:54<00:00, 2954.75draws/s]
# ERROR:pymc3:There were 5 divergences after tuning. Increase `target_accept` or reparameterize.
# ERROR:pymc3:There were 14 divergences after tuning. Increase `target_accept` or reparameterize.

# %%
pm.traceplot(trace, varnames=['slope', 'inter', 'sigma'])
pass

# %%
with pm.Model() as model:
    slope = pm.Uniform('slope',0,30)
    inter = pm.Uniform('inter', 400, 700)
    sigma = pm.Uniform('sigma', 0, 100)

    y_est = slope* dv['years'] + inter
    y = pm.Normal('y', mu=y_est, sd=sigma, observed=dv['italian_mean'])
    trace = pm.sample(10000, tune=30000)
# Out:
# Sampling 4 chains: 100%|██████████| 160000/160000 [00:59<00:00, 2668.52draws/s]
# ERROR:pymc3:There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# WARNING:pymc3:The acceptance probability does not match the target. It is 0.9514567220449962, but should be close to 0.8. Try to increase the number of tuning steps.
# ERROR:pymc3:There were 3 divergences after tuning. Increase `target_accept` or reparameterize.

# %%
pm.traceplot(trace, varnames=['slope', 'inter', 'sigma'])
pass

# %% [markdown]
# Based on the regressions for each of the languages, taking more years of language in Spanish will have the smallest impact on your SAT score, about 10 points. The intercepts and the sigmas are fairly similar for each of the languages and the slopes are all in the 10-15 range. The slope seems to go from largest to smallest for French, German, Italian and then Spanish.
#
# When looking at the final SAT score 10 to 15 points is not a huge difference for each year. This would signify that having known the language your entire life would put you at an advantage over the other students but that an extra year in the language class will not have a huge impact on your score.
#
# In addition, the sigmas are rather large compared to the slopes, ranging from 20-40 for Italian and German, 10-15 for Spanish, and 10-20 for French. This means that there is a lot of flucutation from the increase in score.
#
# Based on this regression if you take more years in a language you are likely to get a higher score on the SAT, however it is not a big difference in the scores between a single year of education. THis is also a SUPER simplified model for an SAT score.
#
# (not a really hard problem - was just curious)
